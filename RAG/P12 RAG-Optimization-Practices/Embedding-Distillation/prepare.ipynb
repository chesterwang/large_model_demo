# %%
cache_dir = '/mnt/workspace/modelscope/'

# 学生模型: BAAI/bge-m3
from modelscope import snapshot_download
model_dir = snapshot_download('BAAI/bge-m3', cache_dir=cache_dir)

# 教师模型: Qwen/Qwen3-Embedding-8B
from modelscope import snapshot_download
model_dir = snapshot_download('Qwen/Qwen3-Embedding-8B', cache_dir=cache_dir)

# %%
# !modelscope download --dataset MTEB/scidocs-reranking --local_dir data/dataset_scidocs

# %%
# !modelscope download --dataset MTEB/stackoverflowdupquestions-reranking --local_dir data/dataset_stackoverflowdupquestions

# %%
# %%bash
# cd data/dataset_scidocs/
# gunzip validation.jsonl.gz
# gunzip test.jsonl.gz
# cd ..

# %%
# %%bash
# cd data/dataset_stackoverflowdupquestions
# gunzip test.jsonl.gz
# cd ..
