# %%
import modelscope
# Out:
# /usr/local/lib/python3.11/site-packages/torch/cuda/__init__.py:56: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]

# %%
from modelscope import snapshot_download
model_dir = snapshot_download('BAAI/bge-reranker-v2-m3', cache_dir='/mnt/workspace/modelscope/')
# Out:
# Downloading Model from https://www.modelscope.cn to directory: /mnt/workspace/modelscope/BAAI/bge-reranker-v2-m3
# 2025-11-09 19:25:39,760 - modelscope - INFO - Got 13 files, start to download ...
# Processing 13 items:   0%|          | 0.00/13.0 [00:00<?, ?it/s]
# Downloading [config.json]:   0%|          | 0.00/795 [00:00<?, ?B/s]
# Downloading [assets/llama-index.png]:   0%|          | 0.00/104k [00:00<?, ?B/s]
# Downloading [model.safetensors]:   0%|          | 0.00/2.12G [00:00<?, ?B/s]
# Downloading [assets/BEIR-bge-en-v1.5.png]:   0%|          | 0.00/55.1k [00:00<?, ?B/s]
# Downloading [assets/miracl-bge-m3.png]:   0%|          | 0.00/50.8k [00:00<?, ?B/s]
# Downloading [assets/BEIR-e5-mistral.png]:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading [configuration.json]:   0%|          | 0.00/77.0 [00:00<?, ?B/s]
# Downloading [assets/CMTEB-retrieval-bge-zh-v1.5.png]:   0%|          | 0.00/50.3k [00:00<?, ?B/s]
# Downloading [README.md]:   0%|          | 0.00/16.8k [00:00<?, ?B/s]
# Downloading [sentencepiece.bpe.model]:   0%|          | 0.00/4.83M [00:00<?, ?B/s]
# Downloading [special_tokens_map.json]:   0%|          | 0.00/964 [00:00<?, ?B/s]
# Downloading [tokenizer.json]:   0%|          | 0.00/16.3M [00:00<?, ?B/s]
# Downloading [tokenizer_config.json]:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# 2025-11-09 19:25:57,201 - modelscope - INFO - Download model 'BAAI/bge-reranker-v2-m3' successfully.

# %%
from modelscope import snapshot_download
model_dir = snapshot_download('Qwen/Qwen3-Reranker-8B', cache_dir='/mnt/workspace/modelscope/')
# Out:
# Downloading Model from https://www.modelscope.cn to directory: /mnt/workspace/modelscope/Qwen/Qwen3-Reranker-8B
# 2025-11-09 19:26:02,937 - modelscope - INFO - Got 14 files, start to download ...
# Processing 14 items:   0%|          | 0.00/14.0 [00:00<?, ?it/s]
# Downloading [model-00001-of-00005.safetensors]:   0%|          | 0.00/3.75G [00:00<?, ?B/s]
# Downloading [model-00002-of-00005.safetensors]:   0%|          | 0.00/3.78G [00:00<?, ?B/s]
# Downloading [model-00003-of-00005.safetensors]:   0%|          | 0.00/3.77G [00:00<?, ?B/s]
# Downloading [configuration.json]:   0%|          | 0.00/73.0 [00:00<?, ?B/s]
# Downloading [merges.txt]:   0%|          | 0.00/1.59M [00:00<?, ?B/s]
# Downloading [generation_config.json]:   0%|          | 0.00/214 [00:00<?, ?B/s]
# Downloading [config.json]:   0%|          | 0.00/729 [00:00<?, ?B/s]
# Downloading [model-00004-of-00005.safetensors]:   0%|          | 0.00/2.80G [00:00<?, ?B/s]
# Downloading [model-00005-of-00005.safetensors]:   0%|          | 0.00/1.16G [00:00<?, ?B/s]
# Downloading [model.safetensors.index.json]:   0%|          | 0.00/32.1k [00:00<?, ?B/s]
# Downloading [README.md]:   0%|          | 0.00/9.63k [00:00<?, ?B/s]
# Downloading [tokenizer.json]:   0%|          | 0.00/10.9M [00:00<?, ?B/s]
# Downloading [tokenizer_config.json]:   0%|          | 0.00/9.48k [00:00<?, ?B/s]
# Downloading [vocab.json]:   0%|          | 0.00/2.65M [00:00<?, ?B/s]
# 2025-11-09 19:27:21,089 - modelscope - INFO - Download model 'Qwen/Qwen3-Reranker-8B' successfully.

# %%
# !modelscope download --dataset MTEB/stackoverflowdupquestions-reranking --local_dir data
# Out:
# /usr/local/lib/python3.11/site-packages/torch/cuda/__init__.py:56: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
#
#  _   .-')                _ .-') _     ('-.             .-')                              _ (`-.    ('-.
# ( '.( OO )_             ( (  OO) )  _(  OO)           ( OO ).                           ( (OO  ) _(  OO)
#  ,--.   ,--.).-'),-----. \     .'_ (,------.,--.     (_)---\_)   .-----.  .-'),-----.  _.`     \(,------.
#  |   `.'   |( OO'  .-.  ',`'--..._) |  .---'|  |.-') /    _ |   '  .--./ ( OO'  .-.  '(__...--'' |  .---'
#  |         |/   |  | |  ||  |  \  ' |  |    |  | OO )\  :` `.   |  |('-. /   |  | |  | |  /  | | |  |
#  |  |'.'|  |\_) |  |\|  ||  |   ' |(|  '--. |  |`-' | '..`''.) /_) |OO  )\_) |  |\|  | |  |_.' |(|  '--.
#  |  |   |  |  \ |  | |  ||  |   / : |  .--'(|  '---.'.-._)   \ ||  |`-'|   \ |  | |  | |  .___.' |  .--'
#  |  |   |  |   `'  '-'  '|  '--'  / |  `---.|      | \       /(_'  '--'\    `'  '-'  ' |  |      |  `---.
#  `--'   `--'     `-----' `-------'  `------'`------'  `-----'    `-----'      `-----'  `--'      `------'
#
# Downloading Dataset to directory: /mnt/workspace/RAG-Optimization-Practices/data
# Processing 4 items:   0%|                           | 0.00/4.00 [00:00<?, ?it/s]
# Downloading [.gitattributes]:   0%|                 | 0.00/1.73k [00:00<?, ?B/s]
#
# Downloading [dataset_infos.json]:   0%|               | 0.00/296 [00:00<?, ?B/s]
#
#
# Downloading [test.jsonl.gz]:   0%|                  | 0.00/1.29M [00:00<?, ?B/s]
#
#
#
# Downloading [train.jsonl.gz]:   0%|                 | 0.00/8.48M [00:00<?, ?B/s]
#
#
#
# Downloading [train.jsonl.gz]:  12%|▉       | 1.00M/8.48M [00:00<00:07, 1.07MB/s]
#
#
# Downloading [test.jsonl.gz]: 100%|█████████| 1.29M/1.29M [00:01<00:00, 1.29MB/s]
# Downloading [train.jsonl.gz]: 100%|████████| 8.48M/8.48M [00:01<00:00, 8.30MB/s]
#
# Downloading [.gitattributes]: 100%|████████| 1.73k/1.73k [00:01<00:00, 1.64kB/s]
#
#
# Downloading [dataset_infos.json]: 100%|██████████| 296/296 [00:01<00:00, 266B/s]
# Processing 4 items: 100%|████████████████████| 4.00/4.00 [00:01<00:00, 3.59it/s]
#
# Successfully Downloaded from dataset MTEB/stackoverflowdupquestions-reranking.

# %%
# !gunzip train.jsonl.gz
# Out:
# gzip: train.jsonl.gz: No such file or directory
