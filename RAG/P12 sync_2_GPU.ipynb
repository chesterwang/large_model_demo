# %%
#增加uv缓存包
# !cd demo_uv/
# !uv add

# %%
#同步uv缓存
! cd  /root/.cache
# !rsync -av uv/   root@IP:/root/.cache/uv

# %%
#同步到GPU服务器
# !cd  /mnt/workspace/
# !rsync -av --exclude .venv  RAG-Optimization-Practices  root@IP:/mnt/workspace/RAG-Optimization-Practices/

# %%
#同步回CPU服务器（因为有些推理结果产生等）
! cd  /mnt/workspace/
# !rsync -av --exclude .venv    root@IP:/mnt/workspace/RAG-Optimization-Practices/ RAG-Optimization-Practices
# Out:
# receiving incremental file list
# .git/
# .git/index
# Reranker-Distillation/
# Reranker-Distillation/evaluate.sh
# Reranker-Distillation/.ipynb_checkpoints/
# Reranker-Distillation/.ipynb_checkpoints/evaluate-checkpoint.sh
# data/reranker_output/
# data/reranker_output/README.md
# data/reranker_output/config.json
# data/reranker_output/model.safetensors
# data/reranker_output/sentencepiece.bpe.model
# data/reranker_output/special_tokens_map.json
# data/reranker_output/tokenizer.json
# data/reranker_output/tokenizer_config.json
# data/reranker_output/checkpoint-1218/
# data/reranker_output/checkpoint-1218/README.md
# data/reranker_output/checkpoint-1218/config.json
# data/reranker_output/checkpoint-1218/model.safetensors
# data/reranker_output/checkpoint-1218/sentencepiece.bpe.model
# data/reranker_output/checkpoint-1218/special_tokens_map.json
# data/reranker_output/checkpoint-1218/tokenizer.json
# data/reranker_output/checkpoint-1218/tokenizer_config.json
# ...
