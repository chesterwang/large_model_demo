# %%
#增加uv缓存包
# !cd demo_uv/
# !uv add

# %%
#同步uv缓存
! cd  /root/.cache
# !rsync -av uv/   root@IP:/root/.cache/uv

# %%
#同步到GPU服务器之前比较差别
# !cd  /mnt/workspace/
# !rsync -avn --itemize-changes --exclude .venv  P12\ RAG-Optimization-Practices/  root@:/mnt/workspace/RAG-Optimization-Practices/

# %%
#同步到GPU服务器
# !cd  /mnt/workspace/
# !rsync -av --exclude .venv  P12\ RAG-Optimization-Practices/  root@:/mnt/workspace/RAG-Optimization-Practices/
# Out:
# sending incremental file list
# Embedding-Distillation/
# Embedding-Distillation/evaluation.sh
# Embedding-Distillation/generate_distillation_data.sh
# Embedding-Distillation/train.sh
# Embedding-Distillation/.ipynb_checkpoints/evaluation-checkpoint.sh
# Embedding-Distillation/.ipynb_checkpoints/generate_distillation_data-checkpoint.sh
# Embedding-Distillation/.ipynb_checkpoints/train-checkpoint.sh
#
# sent 7,354 bytes  received 209 bytes  15,126.00 bytes/sec
# total size is 4,930,355,240  speedup is 651,904.70

# %%
#同步回CPU服务器之前比较差别
# !cd  /mnt/workspace/
# !rsync -avn --itemize-changes --exclude .venv root@:/mnt/workspace/RAG-Optimization-Practices/ P12\ RAG-Optimization-Practices/
# Out:
# receiving incremental file list
# .d..t...... Embedding-Distillation/
# >f.st...... Embedding-Distillation/evaluation.sh
# >f..t...... Embedding-Distillation/generate_distillation_data.sh
# >f..t...... Embedding-Distillation/train.sh
# >f.st...... Embedding-Distillation/.ipynb_checkpoints/evaluation-checkpoint.sh
# >f..t...... Embedding-Distillation/.ipynb_checkpoints/generate_distillation_data-checkpoint.sh
# >f..t...... Embedding-Distillation/.ipynb_checkpoints/train-checkpoint.sh
# .d..t...... Embedding-Distillation/data/dataset_scidocs/
# >f+++++++++ Embedding-Distillation/data/dataset_scidocs/validation_kldiv_distill.jsonl
# >f+++++++++ Embedding-Distillation/data/dataset_scidocs/validation_kldiv_distill_small.jsonl
# .d..t...... Embedding-Distillation/output/
# >f+++++++++ Embedding-Distillation/output/README.md
# >f+++++++++ Embedding-Distillation/output/config.json
# >f+++++++++ Embedding-Distillation/output/config_sentence_transformers.json
# ...

# %%
#同步回CPU服务器（因为有些推理结果产生等）
# !cd  /mnt/workspace/large_model_demo/RAG/
# !rsync -av --exclude .venv root@:/mnt/workspace/RAG-Optimization-Practices/ P12\ RAG-Optimization-Practices/
# Out:
# receiving incremental file list
# Embedding-Distillation/
# Embedding-Distillation/evaluation.sh
# Embedding-Distillation/generate_distillation_data.sh
# Embedding-Distillation/train.sh
# Embedding-Distillation/.ipynb_checkpoints/evaluation-checkpoint.sh
# Embedding-Distillation/.ipynb_checkpoints/generate_distillation_data-checkpoint.sh
# Embedding-Distillation/.ipynb_checkpoints/train-checkpoint.sh
# Embedding-Distillation/data/dataset_scidocs/
# Embedding-Distillation/data/dataset_scidocs/validation_kldiv_distill.jsonl
# Embedding-Distillation/data/dataset_scidocs/validation_kldiv_distill_small.jsonl
# Embedding-Distillation/output/
# Embedding-Distillation/output/README.md
# Embedding-Distillation/output/config.json
# Embedding-Distillation/output/config_sentence_transformers.json
# Embedding-Distillation/output/model.safetensors
# Embedding-Distillation/output/modules.json
# Embedding-Distillation/output/sentence_bert_config.json
# ...
