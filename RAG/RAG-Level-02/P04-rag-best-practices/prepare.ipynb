# %% [markdown]
# # 下载 hb模型

# %%
#通过命令行来下载模型到本地缓存，并且有断点续传的功能。
# 可访问外网
hf download BAAI/bge-large-en-v1.5
# 不可访问外网
from modelscope import snapshot_download
# model_dir = snapshot_download('BAAI/bge-reranker-v2-m3', cache_dir='/mnt/workspace/modelscope/')
model_dir = snapshot_download('BAAI/bge-reranker-large', cache_dir='/mnt/workspace/modelscope/')
